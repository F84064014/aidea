# %%
# !pip3 install sklearn_crfsuite
# Out:
# Requirement already satisfied: sklearn_crfsuite in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (0.3.6)
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from sklearn_crfsuite) (1.14.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from sklearn_crfsuite) (0.9.7)
# Requirement already satisfied: tabulate in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from sklearn_crfsuite) (0.8.7)
# Requirement already satisfied: tqdm>=2.0 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from sklearn_crfsuite) (4.45.0)

# %%
import os
import sys
import numpy as np
import pandas as pd
from tqdm import tqdm

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from sklearn_crfsuite.metrics import flat_classification_report

# %%
def CRF(x_train, y_train, x_test, y_test):
    crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs',
        c1=0.1,
        c2=0.1,
        max_iterations=100,
        all_possible_transitions=True
    )
    crf.fit(x_train, y_train)
#     print(crf) #
    y_pred = crf.predict(x_test)
    y_pred_mar = crf.predict_marginals(x_test)

#     print(y_pred_mar) #

    labels = list(crf.classes_)
    labels.remove('O')
    f1score = metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
    sorted_labels = sorted(labels,key=lambda name: (name[1:], name[0])) # group B and I results
    print(flat_classification_report(y_test, y_pred, labels=sorted_labels, digits=3))
    
#     eli5.show_weights(crf, top=10, feature_re='^word\.is',
#                       horizontal_layout=False, show=['targets'])
    
    return y_pred, y_pred_mar, f1score

# %%
# load pretrained word vectors
# get a dict of tokens (key) and their pretrained word vectors (value)
# pretrained word2vec CBOW word vector: https://fgc.stpi.narl.org.tw/activity/videoDetail/4b1141305ddf5522015de5479f4701b1
dim = 0
word_vecs= {}
# open pretrained word vector file
with open('.\\raw_data\\cna.cbow.cwe_p.tar_g.512d.0.txt', encoding='utf-8') as f:
    for line in f:
        tokens = line.strip().split()

        # there 2 integers in the first line: vocabulary_size, word_vector_dim
        if len(tokens) == 2:
            dim = int(tokens[1])
            continue
    
        word = tokens[0]
        vec = np.array([ float(t) for t in tokens[1:] ])
        word_vecs[word] = vec

# %%
print('vocabulary_size: ',len(word_vecs),' word_vector_dim: ',vec.shape)
# Out:
# vocabulary_size:  158566  word_vector_dim:  (512,)

# %%
# load `train.data` and separate into a list of labeled data of each text
# return:
#   data_list: a list of lists of tuples, storing tokens and labels (wrapped in tuple) of each text in `train.data`
#   traindata_list: a list of lists, storing training data_list splitted from data_list
#   testdata_list: a list of lists, storing testing data_list splitted from data_list
from sklearn.model_selection import train_test_split
def Dataset(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        data=f.readlines()#.encode('utf-8').decode('utf-8-sig')
    data_list, data_list_tmp = list(), list()
    article_id_list=list()
    idx=0
    for row in data:
        data_tuple = tuple()
        if row == '\n':
            article_id_list.append(idx)
            idx+=1
            data_list.append(data_list_tmp)
            data_list_tmp = []
        else:
            row = row.strip('\n').split(' ')
            data_tuple = (row[0], row[1])
            data_list_tmp.append(data_tuple)
    if len(data_list_tmp) != 0:
        data_list.append(data_list_tmp)
    
    # here we random split data into training dataset and testing dataset
    # but you should take `development data` or `test data` as testing data
    # At that time, you could just delete this line, 
    # and generate data_list of `train data` and data_list of `development/test data` by this function
    traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list=train_test_split(data_list,
                                                                                                    article_id_list,
                                                                                                    test_size=0.33,
                                                                                                    random_state=56)
    
    return data_list, traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list

# %%
# open the pos tag file
df_POSTag = pd.read_csv('.\\processed_data\\train2_POSTag.txt')
df_POSTag.head()
# Out:
#    article_id entity_text             POS  length
# 0           0           醫             Na2     NaN
# 1           0           師             Na2     NaN
# 2           0           ：  COLONCATEGORY1     NaN
# 3           0           啊              I1     NaN
# 4           0           回             VA2     NaN

# %%
print(len(df_POSTag['entity_text'].unique()))
print(len(df_POSTag))
print(len(df_POSTag['POS'].unique()))
# Out:
# 1300
# 53703
# 147

# %%
df_POSTag.drop_duplicates(inplace=True)
df_POSTag.head()
text_pool = set(df_POSTag['entity_text'])

# %%
# look up the POSTag txt
# encode the word
def POSTagEncode(data_list, article_id_list):
    
    
    POSTag_list = list()

    df = pd.read_csv('.\\processed_data\\train2_POSTag.txt')
    df = df[df['entity_text'] != ' ']
    POSTag_label = list(df['POS'].unique())
    
    for idx_list in range(len(data_list)):
        df_temp = df[df['article_id']==article_id_list[idx_list]]
        text_temp = list(df_temp['entity_text'])
        POS_temp  = list(df_temp['POS'])
        print(article_id_list[idx_list],'\'',str(len(data_list[idx_list])-len(POS_temp)))
        POSTag_list_temp = list()
        for idx_tuple in range(len(data_list[idx_list])):
            word_POSTag_temp = list()
            for POSTag_label_code in POSTag_label:
                if POS_temp[idx_tuple] == POSTag_label_code:
                    word_POSTag_temp.append(1)
                else:
                    word_POSTag_temp.append(0)
            POSTag_list_temp.append(word_POSTag_temp)
        POSTag_list.append(POSTag_list_temp)

    return POSTag_list

# %%
# look up word vectors
# turn each word into its pretrained word vector
# return a list of word vectors corresponding to each token in train.data
def Word2Vector(data_list, embedding_dict):
    embedding_list = list()

    # No Match Word (unknown word) Vector in Embedding
    unk_vector=np.random.rand(*(list(embedding_dict.values())[0].shape))

    for idx_list in range(len(data_list)):
        embedding_list_tmp = list()
        for idx_tuple in range(len(data_list[idx_list])):
            key = data_list[idx_list][idx_tuple][0] # token

            if key in embedding_dict:
                value = embedding_dict[key]
            else:
                value = unk_vector
            embedding_list_tmp.append(value)
        embedding_list.append(embedding_list_tmp)
    
    return embedding_list

# %%
# input features: pretrained word vectors of each token
# return a list of feature dicts, each feature dict corresponding to each token
def Feature(embed_list, p):
    
    df = pd.read_csv('.\\processed_data\\train2_POSTag.txt')
    POS_unique_list = list(df['POS'].unique())
    POS_unique_list.append('Start') # 1 if no last word
    feature_list = list()
    
    # feature of w2d (original)
    for idx_list in range(len(embed_list)):
        feature_list_tmp = list()
        for idx_tuple in range(len(embed_list[idx_list])):
            
            feature_dict = dict()
            
            # feature of word's POSTag
            feature_dict['Start'] = 0
            for idx_POS in range(len(POS_unique_list)-1): # exclude Start
                feature_dict[POS_unique_list[idx_POS]] = p[idx_list][idx_tuple][idx_POS]
                if idx_tuple != 0:
                    feature_dict['last_' + POS_unique_list[idx_POS]] = p[idx_list][idx_tuple-1][idx_POS]
                else:
                    feature_dict['Start'] = 1
            #-----------------
            for idx_vec in range(len(embed_list[idx_list][idx_tuple])):
                feature_dict['dim_' + str(idx_vec+1)] = embed_list[idx_list][idx_tuple][idx_vec]
            feature_list_tmp.append(feature_dict)
        feature_list.append(feature_list_tmp)
        print(idx_list+1, '\\', len(embed_list)+1, ', # of token:', len(embed_list[idx_list]))
        
    return feature_list

# %%
# get the labels of each tokens in train.data
# return a list of lists of labels
def Preprocess(data_list):
    label_list = list()
    for idx_list in range(len(data_list)):
        label_list_tmp = list()
        for idx_tuple in range(len(data_list[idx_list])):
            label_list_tmp.append(data_list[idx_list][idx_tuple][1])
        label_list.append(label_list_tmp)
    return label_list

# %%
data_list, traindata_list, testdata_list, traindata_article_id_list, testdata_article_id_list = Dataset('.\\data\\train2_sample.data')

# %%
ptrain = POSTagEncode(traindata_list, traindata_article_id_list)
ptest  = POSTagEncode(testdata_list, testdata_article_id_list)
# Out:
# 62 ' 0
# 127 ' 0
# 46 ' 0
# 116 ' 0
# 187 ' 0
# 170 ' 0
# 109 ' 0
# 99 ' 0
# 171 ' 0
# 168 ' 0
# 66 ' 0
# 47 ' 0
# 169 ' 0
# 148 ' 0
# 147 ' 0
# 79 ' 0
# 26 ' 0
# 132 ' 0
# 24 ' 0
# 51 ' 0
# 124 ' 0
# 172 ' 0
# 72 ' 0
# 198 ' 0
# 138 ' 0
# 34 ' 0
# 121 ' 0
# 195 ' 0
# 112 ' 0
# 150 ' 0
# 88 ' 0
# 193 ' 0
# 33 ' 0
# 134 ' 0
# 36 ' 0
# 133 ' 0
# 56 ' 0
# 97 ' 0
# 49 ' 0
# 189 ' 0
# 188 ' 0
# 114 ' 0
# 5 ' 0
# 163 ' 0
# 146 ' 0
# 39 ' 0
# 137 ' 0
# 83 ' 0
# 48 ' 0
# 197 ' 0
# 23 ' 0
# 104 ' 0
# 164 ' 0
# 2 ' 0
# 179 ' 0
# 86 ' 0
# 27 ' 0
# 180 ' 0
# 37 ' 0
# 184 ' 0
# 59 ' 0
# 107 ' 0
# 1 ' 0
# 95 ' 0
# 154 ' 0
# 50 ' 0
# 157 ' 0
# 54 ' 0
# 155 ' 0
# 190 ' 0
# 58 ' 0
# 52 ' 0
# 105 ' 0
# 28 ' 0
# 118 ' 0
# 136 ' 0
# 174 ' 0
# 199 ' 0
# 67 ' 0
# 173 ' 0
# 131 ' 0
# 176 ' 0
# 166 ' 0
# 177 ' 0
# 160 ' 0
# 25 ' 0
# 159 ' 0
# 14 ' 0
# 115 ' 0
# 93 ' 0
# 75 ' 0
# 145 ' 0
# 191 ' 0
# 94 ' 0
# 29 ' 0
# 8 ' 0
# 32 ' 0
# 20 ' 0
# 13 ' 0
# 16 ' 0
# 65 ' 0
# 74 ' 0
# 69 ' 0
# 19 ' 0
# 178 ' 0
# 175 ' 0
# 15 ' 0
# 196 ' 0
# 165 ' 0
# 156 ' 0
# 31 ' 0
# 10 ' 0
# 89 ' 0
# 161 ' 0
# 80 ' 0
# 110 ' 0
# 11 ' 0
# 43 ' 0
# 140 ' 0
# 152 ' 0
# 113 ' 0
# 111 ' 0
# 55 ' 0
# 90 ' 0
# 185 ' 0
# 100 ' 0
# 22 ' 0
# 87 ' 0
# 142 ' 0
# 122 ' 0
# 162 ' 0
# 192 ' 0
# 143 ' 0
# 85 ' 0
# 71 ' 0
# 42 ' 0
# 82 ' 0
# 167 ' 0
# 186 ' 0
# 17 ' 0
# 38 ' 0
# 45 ' 0
# 194 ' 0
# 139 ' 0
# 96 ' 0
# 120 ' 0
# 81 ' 0
# 12 ' 0
# 63 ' 0
# 126 ' 0
# 0 ' 0
# 158 ' 0
# 73 ' 0
# 102 ' 0
# 77 ' 0
# 129 ' 0
# 4 ' 0
# 101 ' 0
# 135 ' 0
# 92 ' 0
# 68 ' 0
# 78 ' 0
# 40 ' 0
# 9 ' 0
# 91 ' 0
# 6 ' 0
# 181 ' 0
# 98 ' 0
# 123 ' 0
# 18 ' 0
# 149 ' 0
# 57 ' 0
# 76 ' 0
# 21 ' 0
# 125 ' 0
# 117 ' 0
# 41 ' 0
# 53 ' 0
# 84 ' 0
# 153 ' 0
# 35 ' 0
# 61 ' 0
# 103 ' 0
# 30 ' 0
# 7 ' 0
# 183 ' 0
# 141 ' 0
# 44 ' 0
# 144 ' 0
# 60 ' 0
# 119 ' 0
# 108 ' 0
# 70 ' 0
# 106 ' 0
# 130 ' 0
# 3 ' 0
# 64 ' 0
# 182 ' 0
# 128 ' 0
# 151 ' 0

# %%
# Load Word Embedding
trainembed_list = Word2Vector(traindata_list, word_vecs)
testembed_list = Word2Vector(testdata_list, word_vecs)

# CRF - Train Data (Augmentation Data)
x_train = Feature(trainembed_list, ptrain)
y_train = Preprocess(traindata_list)

# CRF - Test Data (Golden Standard)
x_test = Feature(testembed_list, ptest)
y_test = Preprocess(testdata_list)
# Out:
# 1 \ 135 , # of token: 1375
# 2 \ 135 , # of token: 1259
# 3 \ 135 , # of token: 2099
# 4 \ 135 , # of token: 2861
# 5 \ 135 , # of token: 1827
# 6 \ 135 , # of token: 2345
# 7 \ 135 , # of token: 1791
# 8 \ 135 , # of token: 3335
# 9 \ 135 , # of token: 2675
# 10 \ 135 , # of token: 4396
# 11 \ 135 , # of token: 661
# 12 \ 135 , # of token: 1607
# 13 \ 135 , # of token: 1326
# 14 \ 135 , # of token: 1466
# 15 \ 135 , # of token: 2925
# 16 \ 135 , # of token: 4079
# 17 \ 135 , # of token: 3369
# 18 \ 135 , # of token: 2156
# 19 \ 135 , # of token: 1702
# 20 \ 135 , # of token: 1718
# 21 \ 135 , # of token: 4435
# 22 \ 135 , # of token: 3731
# 23 \ 135 , # of token: 3689
# 24 \ 135 , # of token: 1185
# 25 \ 135 , # of token: 936
# 26 \ 135 , # of token: 956
# 27 \ 135 , # of token: 2214
# 28 \ 135 , # of token: 1988
# 29 \ 135 , # of token: 7309
# 30 \ 135 , # of token: 575
# 31 \ 135 , # of token: 1077
# 32 \ 135 , # of token: 2829
# 33 \ 135 , # of token: 1760
# 34 \ 135 , # of token: 823
# 35 \ 135 , # of token: 5276
# 36 \ 135 , # of token: 637
# 37 \ 135 , # of token: 2519
# 38 \ 135 , # of token: 2184
# 39 \ 135 , # of token: 1215
# 40 \ 135 , # of token: 1840
# 41 \ 135 , # of token: 2618
# 42 \ 135 , # of token: 4065
# 43 \ 135 , # of token: 567
# 44 \ 135 , # of token: 2011
# 45 \ 135 , # of token: 979
# 46 \ 135 , # of token: 1871
# 47 \ 135 , # of token: 1745
# 48 \ 135 , # of token: 2075
# 49 \ 135 , # of token: 3458
# 50 \ 135 , # of token: 1522
# 51 \ 135 , # of token: 1633
# 52 \ 135 , # of token: 3490
# 53 \ 135 , # of token: 4635
# 54 \ 135 , # of token: 1689
# 55 \ 135 , # of token: 3758
# 56 \ 135 , # of token: 954
# 57 \ 135 , # of token: 4294
# 58 \ 135 , # of token: 2101
# 59 \ 135 , # of token: 882
# 60 \ 135 , # of token: 846
# 61 \ 135 , # of token: 1182
# 62 \ 135 , # of token: 2278
# 63 \ 135 , # of token: 2652
# 64 \ 135 , # of token: 1752
# 65 \ 135 , # of token: 7654
# 66 \ 135 , # of token: 2609
# 67 \ 135 , # of token: 1115
# 68 \ 135 , # of token: 1694
# 69 \ 135 , # of token: 2549
# 70 \ 135 , # of token: 1759
# 71 \ 135 , # of token: 2360
# 72 \ 135 , # of token: 581
# 73 \ 135 , # of token: 2678
# 74 \ 135 , # of token: 1588
# 75 \ 135 , # of token: 3929
# 76 \ 135 , # of token: 2191
# 77 \ 135 , # of token: 2076
# 78 \ 135 , # of token: 1080
# 79 \ 135 , # of token: 1083
# 80 \ 135 , # of token: 2613
# 81 \ 135 , # of token: 977
# 82 \ 135 , # of token: 2181
# 83 \ 135 , # of token: 1595
# 84 \ 135 , # of token: 2393
# 85 \ 135 , # of token: 739
# 86 \ 135 , # of token: 1597
# 87 \ 135 , # of token: 2882
# 88 \ 135 , # of token: 1340
# 89 \ 135 , # of token: 5638
# 90 \ 135 , # of token: 2075
# 91 \ 135 , # of token: 633
# 92 \ 135 , # of token: 1380
# 93 \ 135 , # of token: 2130
# 94 \ 135 , # of token: 4830
# 95 \ 135 , # of token: 1495
# 96 \ 135 , # of token: 1134
# 97 \ 135 , # of token: 2970
# 98 \ 135 , # of token: 1282
# 99 \ 135 , # of token: 1229
# 100 \ 135 , # of token: 3635
# 101 \ 135 , # of token: 1198
# 102 \ 135 , # of token: 984
# 103 \ 135 , # of token: 1686
# 104 \ 135 , # of token: 2603
# 105 \ 135 , # of token: 1550
# 106 \ 135 , # of token: 2402
# 107 \ 135 , # of token: 1645
# 108 \ 135 , # of token: 1394
# 109 \ 135 , # of token: 1311
# 110 \ 135 , # of token: 1728
# 111 \ 135 , # of token: 1142
# 112 \ 135 , # of token: 710
# 113 \ 135 , # of token: 1777
# 114 \ 135 , # of token: 3229
# 115 \ 135 , # of token: 2430
# 116 \ 135 , # of token: 1685
# 117 \ 135 , # of token: 3503
# 118 \ 135 , # of token: 2976
# 119 \ 135 , # of token: 380
# 120 \ 135 , # of token: 1233
# 121 \ 135 , # of token: 1642
# 122 \ 135 , # of token: 1399
# 123 \ 135 , # of token: 1227
# 124 \ 135 , # of token: 1764
# 125 \ 135 , # of token: 2882
# 126 \ 135 , # of token: 2024
# 127 \ 135 , # of token: 3463
# 128 \ 135 , # of token: 1157
# 129 \ 135 , # of token: 1790
# 130 \ 135 , # of token: 1169
# 131 \ 135 , # of token: 3248
# 132 \ 135 , # of token: 912
# 133 \ 135 , # of token: 2665
# 134 \ 135 , # of token: 2747
# 1 \ 67 , # of token: 3081
# 2 \ 67 , # of token: 1163
# 3 \ 67 , # of token: 1816
# 4 \ 67 , # of token: 1448
# 5 \ 67 , # of token: 2731
# 6 \ 67 , # of token: 1204
# 7 \ 67 , # of token: 2030
# 8 \ 67 , # of token: 2453
# 9 \ 67 , # of token: 992
# 10 \ 67 , # of token: 1184
# 11 \ 67 , # of token: 3233
# 12 \ 67 , # of token: 1345
# 13 \ 67 , # of token: 1375
# 14 \ 67 , # of token: 1933
# 15 \ 67 , # of token: 1000
# 16 \ 67 , # of token: 1745
# 17 \ 67 , # of token: 4211
# 18 \ 67 , # of token: 1172
# 19 \ 67 , # of token: 1287
# 20 \ 67 , # of token: 3159
# 21 \ 67 , # of token: 2348
# 22 \ 67 , # of token: 1866
# 23 \ 67 , # of token: 767
# 24 \ 67 , # of token: 1512
# 25 \ 67 , # of token: 2228
# 26 \ 67 , # of token: 1847
# 27 \ 67 , # of token: 2404
# 28 \ 67 , # of token: 1268
# 29 \ 67 , # of token: 1596
# 30 \ 67 , # of token: 2213
# 31 \ 67 , # of token: 1094
# 32 \ 67 , # of token: 3101
# 33 \ 67 , # of token: 2690
# 34 \ 67 , # of token: 1481
# 35 \ 67 , # of token: 1039
# 36 \ 67 , # of token: 2051
# 37 \ 67 , # of token: 3395
# 38 \ 67 , # of token: 2168
# 39 \ 67 , # of token: 1331
# 40 \ 67 , # of token: 1809
# 41 \ 67 , # of token: 699
# 42 \ 67 , # of token: 2615
# 43 \ 67 , # of token: 1590
# 44 \ 67 , # of token: 1047
# 45 \ 67 , # of token: 2274
# 46 \ 67 , # of token: 1901
# 47 \ 67 , # of token: 2459
# 48 \ 67 , # of token: 1384
# 49 \ 67 , # of token: 3286
# 50 \ 67 , # of token: 3755
# 51 \ 67 , # of token: 1790
# 52 \ 67 , # of token: 2086
# 53 \ 67 , # of token: 1678
# 54 \ 67 , # of token: 1738
# 55 \ 67 , # of token: 2509
# 56 \ 67 , # of token: 1090
# 57 \ 67 , # of token: 1357
# 58 \ 67 , # of token: 2824
# 59 \ 67 , # of token: 1074
# 60 \ 67 , # of token: 1520
# 61 \ 67 , # of token: 1352
# 62 \ 67 , # of token: 1229
# 63 \ 67 , # of token: 1659
# 64 \ 67 , # of token: 3284
# 65 \ 67 , # of token: 3300
# 66 \ 67 , # of token: 695

# %%
print(len(ptrain))
print(len(ptrain[0]))
print(len(ptrain[0][0]))

print(len(trainembed_list))
print(len(trainembed_list[0]))
print(len(trainembed_list[0][0]))
# Out:
# 134
# 1375
# 181
# 134
# 1375
# 512

# %%
# each word with 521 dimension
print(x_train[0][1]['dim_1'])
print(len(x_train[0][1]))
print(y_train[0][0])
# Out:
# 1.148426
# 875
# O

# %%
y_pred, y_pred_mar, f1score = CRF(x_train, y_train, x_test, y_test)
# Out:
#                   precision    recall  f1-score   support
#
#             B-ID      0.000     0.000     0.000         3
#             I-ID      0.000     0.000     0.000         7
# B-clinical_event      0.000     0.000     0.000         1
# I-clinical_event      0.000     0.000     0.000         3
#        B-contact      0.000     0.000     0.000        29
#        I-contact      0.000     0.000     0.000       107
#      B-education      0.000     0.000     0.000         3
#      I-education      0.000     0.000     0.000         9
#         B-family      0.250     0.091     0.133        11
#         I-family      0.250     0.091     0.133        11
#       B-location      0.784     0.843     0.812       108
#       I-location      0.762     0.767     0.765       159
#       B-med_exam      0.571     0.066     0.118       182
#       I-med_exam      0.604     0.078     0.138       371
#          B-money      0.714     0.222     0.339        45
#          I-money      0.694     0.217     0.331       115
#           B-name      0.803     0.570     0.667       100
#           I-name      0.814     0.590     0.684       178
#     B-profession      0.000     0.000     0.000        17
#     I-profession      0.000     0.000     0.000        32
#           B-time      0.773     0.602     0.677       807
#           I-time      0.824     0.671     0.740      1805
#
#        micro avg      0.760     0.524     0.620      4103
#        macro avg      0.357     0.219     0.252      4103
#     weighted avg      0.728     0.524     0.587      4103

# %%
f1score
# Out:
# 0.586899510662267

# %%
output="article_id\tstart_position\tend_position\tentity_text\tentity_type\n"
for test_id in range(len(y_pred)):
    pos=0
    start_pos=None
    end_pos=None
    entity_text=None
    entity_type=None
    for pred_id in range(len(y_pred[test_id])):
        if y_pred[test_id][pred_id][0]=='B':
            start_pos=pos
            entity_type=y_pred[test_id][pred_id][2:]
        elif start_pos is not None and y_pred[test_id][pred_id][0]=='I' and y_pred[test_id][pred_id+1][0]=='O':
            end_pos=pos
            entity_text=''.join([testdata_list[test_id][position][0] for position in range(start_pos,end_pos+1)])
            line=str(testdata_article_id_list[test_id])+'\t'+str(start_pos)+'\t'+str(end_pos+1)+'\t'+entity_text+'\t'+entity_type
            output+=line+'\n'
        pos+=1

# %%
output_path='output.tsv'
with open(output_path,'w',encoding='utf-8') as f:
    f.write(output)

# %%
print(output)
# Out:
# article_id	start_position	end_position	entity_text	entity_type
# 71	9	12	兩個月	time
# 71	32	37	兩個小時前	time
# 71	79	82	兩個月	time
# 71	213	216	兩個月	time
# 71	329	331	兩年	time
# 71	2805	2807	兩天	time
# 42	180	183	五個月	time
# 42	278	281	兩個月	time
# 42	329	332	兩個月	time
# 42	554	559	8月25號	time
# 42	901	905	兩個禮拜	time
# 42	941	944	五個月	time
# 42	950	953	五個月	time
# 82	4	7	這個月	time
# 82	191	196	這一天禮拜	time
# 82	197	202	今天禮拜四	time
# 82	217	219	禮拜	time
# 82	222	225	禮拜五	time
# 82	390	392	八點	time
# 82	416	419	八點一	med_exam
# 82	428	430	禮拜	time
# 82	444	446	禮拜	time
# 82	485	490	禮拜五晚上	time
# 82	523	525	八點	time
# 82	575	579	7月1號	time
# 82	584	588	7月1號	time
# 82	593	595	八點	time
# 82	854	857	這個月	time
# 167	16	19	這個月	time
# 167	147	151	下下禮拜	time
# 167	172	176	下下禮拜	time
# 167	183	188	禮拜五早上	time
# 167	241	245	第八個月	time
# 167	413	415	台中	location
# 167	420	422	新竹	location
# 167	524	526	新竹	location
# 167	636	640	第八個月	time
# 167	659	662	下禮拜	time
# 167	718	721	禮拜四	time
# 167	726	728	下午	time
# 167	790	794	第九個月	time
# 167	803	807	十月九號	time
# 167	826	829	前一天	time
# 167	844	847	前一週	time
# 167	852	855	下一週	time
# 167	887	892	九號禮拜三	time
# 167	963	965	新竹	location
# 167	978	981	李醫師	name
# 167	988	991	李醫師	name
# 167	1128	1131	十二月	time
# 167	1246	1248	李允	name
# 167	1264	1267	李醫師	name
# 186	235	237	中午	time
# 186	254	256	中午	time
# 186	527	531	奇美醫院	location
# 186	802	805	三個月	time
# 186	933	936	陳醫師	name
# 186	988	992	兩百多萬	money
# 186	997	1001	兩百多萬	money
# 186	1021	1025	兩百多萬	money
# 186	1052	1055	五個月	time
# 186	1394	1396	四年	time
# 186	1404	1406	四年	time
# 186	1414	1416	四年	time
# 186	2259	2263	一個半月	time
# 186	2295	2299	兩個禮拜	time
# 186	2334	2338	三個禮拜	time
# 186	2404	2407	陳醫師	name
# 17	487	491	兩個禮拜	time
# 17	822	826	兩個禮拜	time
# 17	848	853	下下個禮拜	time
# 17	876	879	下禮拜	time
# 17	897	900	禮拜二	time
# 17	909	912	禮拜二	time
# 17	944	948	兩個禮拜	time
# 38	119	122	兩個月	time
# 38	406	409	七十幾	med_exam
# 38	522	524	前年	time
# 38	579	581	前年	time
# 38	623	625	兩年	time
# 38	644	646	兩年	time
# 38	689	691	兩年	time
# 38	786	788	前年	time
# 38	789	799	十月、十一月、十二月	time
# 38	843	848	二十幾公斤	med_exam
# 38	1164	1166	五百	med_exam
# 38	1290	1293	三百八	med_exam
# 38	1315	1318	兩個月	time
# 38	1325	1328	兩個月	time
# 38	1339	1343	一個禮拜	time
# 38	1349	1351	小美	name
# 38	1505	1508	工業區	profession
# 38	1559	1561	台東	location
# 38	1563	1565	台東	location
# 38	1674	1676	台東	location
# 38	1686	1689	中正路	location
# 38	1700	1702	小美	name
# 38	1721	1724	一個月	time
# 38	1895	1897	台東	location
# 38	1937	1940	九月中	time
# 38	1990	1992	台東	location
# 45	7	10	林小姐	name
# 45	750	752	明天	time
# 45	759	761	明天	time
# 45	1262	1264	明天	time
# 45	1946	1948	前天	time
# 45	2167	2174	下下個禮拜幾號	time
# 45	2281	2285	下下禮拜	time
# 45	2289	2293	下下個月	time
# 45	2298	2302	下下個月	time
# 45	2308	2310	八號	time
# 45	2313	2315	榮總	location
# 45	2322	2324	榮總	location
# 45	2340	2344	九月八號	time
# 45	2357	2361	九月十號	time
# 45	2382	2386	九月十號	time
# 45	2387	2390	禮拜五	time
# 45	2394	2397	禮拜五	time
# 194	70	74	兩千多塊	money
# 194	274	276	四天	time
# 194	290	294	四十分鐘	time
# 139	3	5	阿明	name
# 139	12	17	5月22號	time
# 139	336	339	三個月	time
# 139	355	358	林醫師	name
# 139	416	419	十年多	time
# 139	1172	1175	林醫師	name
# 96	75	77	兩年	time
# 96	492	494	台東	location
# 96	504	506	台東	location
# 96	511	513	台東	location
# 96	519	521	台東	location
# 96	533	535	紐約	location
# 96	1843	1846	這個月	time
# 96	1931	1935	兩個禮拜	time
# 96	1957	1959	泰國	location
# 96	2733	2736	六月中	time
# 96	2750	2755	6月15號	time
# 96	3036	3041	美國在英國	location
# 96	3042	3044	澳洲	family
# 120	52	55	上禮拜	time
# 120	464	466	早上	time
# 120	482	484	早上	time
# 120	510	512	早上	time
# 120	633	635	台大	location
# 120	997	1000	王小明	name
# 120	1026	1029	王醫師	name
# 120	1122	1125	9月底	time
# 120	1153	1155	吳大	name
# 120	1204	1209	9月28號	time
# 120	1214	1219	10月2號	time
# 81	406	410	一個禮拜	time
# 81	686	689	這個月	time
# 12	156	161	5月29號	time
# 12	637	639	二月	time
# 12	644	646	二月	time
# 12	923	926	兩三天	time
# 12	1262	1264	兩年	time
# 12	1272	1274	兩年	time
# 63	115	117	小美	name
# 63	247	250	四個月	time
# 63	394	398	一個禮拜	time
# 63	400	405	一兩個禮拜	time
# 63	410	415	一兩個禮拜	time
# 63	873	878	9月28號	time
# 126	362	366	十一點多	time
# 126	437	441	高雄大學	location
# 126	486	490	兩三學分	time
# 126	1199	1203	第二個月	time
# 126	1287	1290	禮拜三	time
# 126	1299	1302	禮拜三	time
# 126	1316	1319	禮拜三	time
# 126	1327	1330	禮拜三	time
# 126	1413	1416	禮拜五	time
# 126	1417	1421	四個禮拜	time
# 126	1452	1455	禮拜五	time
# 126	1515	1517	三週	time
# 126	1518	1521	三個月	time
# 126	1666	1669	一個月	time
# 126	1678	1681	下個月	time
# 126	1687	1690	禮拜五	time
# 126	1708	1711	禮拜五	time
# 126	1721	1728	禮拜三和禮拜五	time
# 126	1729	1731	下午	time
# 126	1733	1736	禮拜一	time
# 126	1737	1739	早上	time
# 0	69	71	前天	time
# 0	75	77	前天	time
# 0	233	241	negative	profession
# 0	245	253	negative	profession
# 0	277	285	negative	profession
# 0	455	457	山區	location
# 0	809	811	前年	time
# 0	844	846	前年	time
# 0	859	861	前年	time
# 0	1048	1052	三月十八	time
# 0	1851	1859	reactive	profession
# 0	2229	2232	兩個月	time
# 0	2280	2282	伯斯	name
# 0	2313	2317	下下禮拜	time
# 0	2325	2329	下下禮拜	time
# 0	2362	2367	三月二十一	time
# 0	2375	2379	兩個禮拜	time
# 0	2556	2560	兩個禮拜	time
# 0	2817	2819	美國	location
# 0	2844	2846	紐約	location
# 0	2854	2856	紐約	location
# 0	2870	2873	新社區	location
# 0	2996	3000	下下禮拜	time
# 0	3306	3310	下下禮拜	time
# 0	3335	3337	七號	time
# 0	3341	3343	四月	time
# 0	3350	3355	今天二十號	time
# 0	3360	3366	下下禮拜七號	time
# 0	3371	3377	下下禮拜九號	time
# 0	3383	3387	四月四號	time
# 0	3729	3731	五天	time
# 0	4191	4196	一百五十塊	money
# 158	312	315	禮拜三	time
# 158	316	319	禮拜四	time
# 158	540	548	OKOKOKOK	profession
# 158	1007	1011	第七個月	time
# 158	1026	1029	下個月	time
# 158	1058	1060	兩周	time
# 158	1062	1065	端午節	time
# 158	1072	1074	一周	time
# 158	1078	1082	6月2號	time
# 73	145	147	小美	name
# 73	188	191	兩年半	time
# 73	196	199	兩年半	time
# 73	235	238	4月份	time
# 73	243	245	兩年	time
# 73	496	498	北韓	location
# 73	815	818	一個月	time
# 102	6	9	兩個月	time
# 102	208	211	兩個月	time
# 102	1324	1328	第七個月	time
# 102	1334	1338	第七個月	time
# 102	1443	1445	東京	location
# 102	1509	1511	今年	time
# 102	1721	1725	六千多塊	money
# 102	1740	1743	一萬八	money
# 102	1803	1806	一萬八	money
# 102	1818	1821	一萬八	money
# 102	1844	1847	一個月	time
# 102	1887	1890	一萬八	money
# 102	2029	2031	泰國	location
# 102	2039	2041	泰國	location
# 102	2112	2114	日本	location
# 102	2187	2189	日本	location
# 102	2300	2302	東京	location
# 102	2341	2343	九百	med_exam
# 102	2412	2414	東京	location
# 102	2422	2426	東京醫院	location
# 102	2440	2443	宇智波	location
# 102	2516	2518	東京	location
# 102	2575	2578	五個月	time
# 102	2609	2612	兩個月	time
# 102	2684	2687	下個月	time
# 102	2846	2848	日本	location
# 102	2962	2966	十二個月	time
# 102	2974	2976	日本	location
# 102	3073	3076	泰國學	location
# 102	3133	3135	泰國	location
# 77	573	578	兩個禮拜一	time
# 77	591	594	兩個月	time
# 77	859	864	兩個禮拜一	time
# 77	1017	1020	禮拜一	time
# 77	1107	1109	六日	time
# 77	2181	2184	兩三天	time
# 129	4	6	櫻木	location
# 129	848	851	三個月	time
# 129	858	861	三個月	time
# 129	874	877	三個月	time
# 129	928	931	三個月	time
# 129	955	958	三個月	time
# 129	977	983	10月15號	time
# 129	1327	1329	三年	time
# 129	1384	1386	爺爺	family
# 129	1596	1598	今天	time
# 101	203	207	今天早上	time
# 101	211	213	中午	time
# 101	658	663	今天禮拜四	time
# 101	676	679	禮拜四	time
# 101	1318	1322	九月五號	time
# 101	1326	1330	九月五號	time
# 101	1414	1418	兩個禮拜	time
# 135	889	891	下午	time
# 135	895	897	下午	time
# 135	1242	1244	早上	time
# 135	1617	1620	上個月	time
# 135	1626	1629	上個月	time
# 135	1633	1636	上個月	time
# 135	1637	1641	前三個月	time
# 92	56	58	下午	time
# 92	98	100	下午	time
# 92	160	163	這個月	time
# 92	274	278	第三個月	time
# 92	339	341	4月	time
# 92	534	538	第三個月	time
# 92	539	543	第二個月	time
# 92	555	559	第三個月	time
# 92	629	633	8月1號	time
# 92	766	779	Hornet，Grindr	profession
# 92	1601	1603	8月	time
# 92	1609	1613	8月2號	time
# 68	8	11	兩個月	time
# 68	175	178	兩個月	time
# 68	347	350	兩個月	time
# 78	208	211	這個月	time
# 40	401	405	下下禮拜	time
# 40	429	434	10月7號	time
# 40	443	447	下下禮拜	time
# 40	450	452	四周	time
# 40	491	495	四個禮拜	time
# 40	524	528	上個禮拜	time
# 40	536	540	上個禮拜	time
# 40	549	553	上個禮拜	time
# 40	569	574	下下個禮拜	time
# 40	644	649	下下個禮拜	time
# 40	653	656	禮拜二	time
# 40	999	1003	下下禮拜	time
# 40	1008	1013	11月2號	time
# 40	1214	1220	DEXONE	profession
# 40	1231	1237	Clinda	profession
# 40	1254	1260	DEXONE	profession
# 40	1273	1276	禮拜三	time
# 40	1487	1491	下下禮拜	time
# 40	1496	1500	下下禮拜	time
# 40	1508	1510	四周	time
# 40	1535	1540	禮拜二早上	time
# 40	1547	1549	小櫻	name
# 9	1333	1336	禮拜三	time
# 9	1340	1345	下個禮拜三	time
# 9	1350	1353	禮拜三	time
# 9	1396	1398	下午	time
# 9	1406	1408	下午	time
# 9	1434	1437	上午時	time
# 9	1442	1445	下午時	time
# 9	1510	1513	禮拜五	time
# 9	1533	1537	下禮拜五	time
# 9	1552	1556	下禮拜五	time
# 9	1557	1560	四月二	time
# 9	1570	1573	四月二	time
# 9	1578	1583	四月十三號	time
# 9	1592	1595	二十號	time
# 9	1601	1604	二十號	time
# 9	1615	1618	二十號	time
# 9	1623	1626	第八號	time
# 9	1635	1638	禮拜五	time
# 9	1647	1652	下午第八號	time
# 9	1687	1692	四月二十號	time
# 9	1708	1711	四月二	time
# 9	1718	1721	第八號	time
# 9	1867	1869	六月	time
# 9	1881	1885	六月一號	time
# 9	1998	2002	六月一號	time
# 9	2144	2147	兩個月	time
# 91	15	19	前二個月	time
# 91	165	169	前兩個月	time
# 91	178	182	前兩個月	time
# 91	195	198	兩個月	time
# 91	1034	1039	8月19號	time
# 6	1508	1511	前一天	time
# 6	1624	1627	6月初	time
# 6	1652	1657	6月21日	time
# 6	1658	1663	6月21號	time
# 6	1664	1669	6月21號	time
# 6	1677	1682	6月24號	time
# 6	1684	1689	6月25號	time
# 6	1823	1825	中午	time
# 6	1852	1854	中午	time
# 6	1920	1922	中午	time
# 6	2454	2456	半路	location
# 6	2477	2482	6月15號	time
# 6	2486	2489	禮拜三	time
# 6	2949	2954	6月24號	time
# 181	4	7	黃醫師	name
# 181	136	138	去年	time
# 181	147	149	7月	time
# 181	203	206	三個月	time
# 181	242	249	去年7月20號	time
# 181	253	258	7月20號	time
# 181	307	310	三個月	time
# 181	784	788	三個禮拜	time
# 181	797	801	三個禮拜	time
# 181	826	830	三個禮拜	time
# 181	831	833	四週	time
# 181	1028	1033	上上個禮拜	time
# 181	1041	1045	上上禮拜	time
# 181	1253	1255	台中	location
# 181	1395	1397	平日	time
# 181	1502	1504	老公	family
# 181	1511	1513	下午	time
# 181	1623	1625	德國	location
# 181	1640	1642	德國	location
# 181	1645	1647	瑞典	location
# 181	1738	1740	德國	location
# 181	1742	1744	瑞典	location
# 98	154	156	前天	time
# 98	158	160	前天	time
# 98	161	163	前天	time
# 98	468	470	小明	name
# 98	1134	1138	第五個月	time
# 98	1164	1166	6月	time
# 98	1175	1177	6月	time
# 98	1224	1226	小美	name
# 123	3	5	小明	name
# 123	89	95	5月18號一	time
# 123	757	759	台東	location
# 123	763	765	台東	location
# 123	776	778	學校	location
# 18	23	26	六點多	time
# 18	34	37	六點多	time
# 18	958	960	兩年	time
# 18	1000	1002	兩年	time
# 18	1005	1007	前年	time
# 18	1008	1013	四月二十七	time
# 18	1029	1031	今年	time
# 18	1032	1036	五月三號	time
# 18	1059	1063	五月三號	time
# 18	1072	1076	六個禮拜	time
# 18	1118	1122	兩個禮拜	time
# 18	1162	1165	九十六	med_exam
# 18	1407	1415	lowspeed	profession
# 18	1539	1544	八百七十二	med_exam
# 18	1748	1751	兩個月	time
# 18	1815	1818	兩個月	time
# 18	1822	1825	禮拜四	time
# 18	1827	1831	七月三號	time
# 18	1832	1835	端午節	time
# 18	1849	1853	七月二號	time
# 18	1889	1891	早上	time
# 18	1898	1900	早上	time
# 18	1921	1923	小美	name
# 18	1924	1931	七月四號禮拜五	time
# 18	1942	1946	七月四號	time
# 18	1996	1999	第三號	time
# 149	277	279	竹科	location
# 149	910	912	社區	location
# 149	1273	1275	兩周	time
# 149	1281	1283	兩周	time
# 149	1336	1340	前三四天	time
# 149	1368	1372	十三小時	time
# 149	1376	1380	十三小時	time
# 149	1437	1439	兩周	time
# 149	1444	1446	八天	time
# 149	1450	1452	兩周	time
# 149	1458	1460	兩周	time
# 149	1492	1496	下禮拜三	time
# 149	1801	1803	六日	time
# 149	1837	1839	兩周	time
# 149	1854	1857	禮拜三	time
# 149	1858	1862	下禮拜三	time
# 149	2174	2177	四歲多	time
# 149	2206	2212	一歲八九個月	time
# 149	2216	2218	兩歲	time
# 149	2475	2486	CMV、EVV、HIV	profession
# 149	2914	2917	下下周	time
# 149	2926	2929	下下周	time
# 149	3162	3164	下午	time
# 57	309	312	兩個月	time
# 57	1210	1214	紐約醫院	location
# 57	1236	1240	紐約醫院	location
# 57	1251	1255	紐約醫院	location
# 57	1259	1263	紐約醫院	location
# 57	1636	1639	李醫師	name
# 76	185	188	兩個月	time
# 21	18	23	一百五十塊	money
# 21	42	45	林醫師	name
# 21	266	268	前天	time
# 21	363	365	前天	time
# 21	667	669	明天	time
# 21	783	786	陳醫師	name
# 21	971	973	小美	name
# 21	980	983	林醫師	name
# 21	987	990	林醫師	name
# 21	1122	1126	上上禮拜	time
# 21	1368	1372	三個禮拜	time
# 21	1378	1382	三個禮拜	time
# 21	1385	1388	黃醫師	name
# 21	1389	1392	黃醫師	name
# 21	1394	1399	五月二十八	time
# 21	1404	1407	五二八	med_exam
# 21	1412	1415	五二八	med_exam
# 21	1427	1430	五二八	med_exam
# 21	1594	1596	台北	location
# 21	1597	1599	士林	location
# 21	1605	1607	台北	location
# 21	1614	1618	台北士林	location
# 21	1628	1630	台北	location
# 21	1631	1633	士林	location
# 21	1637	1639	台北	location
# 21	1641	1643	士林	location
# 21	1646	1648	士林	location
# 21	1652	1654	士林	location
# 21	1660	1662	士林	location
# 125	561	564	下禮拜	time
# 125	565	568	下禮拜	time
# 125	602	605	下禮拜	time
# 125	621	625	下禮拜五	time
# 117	3	6	這個月	time
# 117	13	16	這個月	time
# 117	1901	1906	2年3個月	time
# 117	2197	2199	4月	time
# 117	2210	2213	7月底	time
# 117	2230	2233	7月底	time
# 117	2385	2388	下個月	time
# 117	2507	2511	8月8號	time
# 117	2590	2592	高雄	location
# 41	142	144	五十	time
# 41	155	157	五十	time
# 41	187	190	林醫師	name
# 41	191	193	八月	time
# 41	202	206	九月十號	time
# 41	209	213	兩個禮拜	time
# 41	215	218	林醫師	name
# 41	228	232	兩個禮拜	time
# 41	284	288	九月十號	time
# 41	292	296	九月十號	time
# 41	351	353	上午	time
# 41	362	364	上午	time
# 41	479	482	林醫師	name
# 41	591	594	七點多	time
# 41	610	614	五點五八	time
# 41	620	624	五點五八	time
# 41	673	676	九點三	med_exam
# 41	680	683	九點三	med_exam
# 41	708	711	九點六	med_exam
# 41	758	762	九月十號	time
# 41	871	875	六十二歲	time
# 41	1284	1286	五十	time
# 41	1344	1348	二十八天	time
# 41	1352	1356	九月十號	time
# 41	1362	1366	九月十日	time
# 41	1367	1370	十四天	time
# 41	1374	1377	十四天	time
# 41	1403	1407	兩個禮拜	time
# 41	1408	1412	兩個禮拜	time
# 41	1419	1423	兩個禮拜	time
# 41	1424	1428	兩個禮拜	time
# 41	1438	1441	林醫師	name
# 41	1482	1486	兩個禮拜	time
# 41	1575	1579	九月十號	time
# 41	1583	1587	九月十號	time
# 53	5	8	八點五	med_exam
# 53	28	32	十八點七	time
# 53	361	363	下午	time
# 53	368	370	下午	time
# 53	376	379	上禮拜	time
# 53	507	510	廖醫師	name
# 53	522	525	李醫師	name
# 53	568	571	兩個月	time
# 53	611	615	兩個禮拜	time
# 53	637	641	兩個禮拜	time
# 53	655	657	四週	time
# 53	943	947	四個禮拜	time
# 53	982	986	四個禮拜	time
# 53	998	1002	十月二號	time
# 84	192	196	這一個月	time
# 84	394	397	杜蕾斯	name
# 84	470	473	杜蕾斯	name
# 84	478	480	岡本	location
# 84	502	504	岡本	location
# 84	528	530	岡本	location
# 84	536	538	岡本	location
# 84	596	598	岡本	location
# 153	1133	1135	兩年	time
# 153	1141	1143	兩年	time
# 35	376	379	尼西林	location
# 35	384	388	盤尼西林	location
# 35	426	429	兩年多	time
# 35	446	450	去年3月	time
# 35	578	584	3月2019	time
# 35	667	669	7月	time
# 35	1133	1137	下禮拜二	time
# 35	1687	1691	盤尼西林	location
# 35	2024	2030	11月10號	time
# 61	6	9	林醫師	name
# 61	777	781	兩個禮拜	time
# 61	912	915	李醫師	name
# 61	1175	1178	林醫師	name
# 103	28	30	兩年	time
# 103	274	276	一號	time
# 103	825	830	這兩三個月	time
# 103	1395	1397	一號	time
# 103	1934	1938	晚上八點	time
# 103	1977	1980	前兩天	time
# 103	2109	2113	晚上八點	time
# 103	2850	2853	下禮拜	time
# 103	2854	2857	下個月	time
# 103	3205	3207	9月	time
# 103	3213	3215	9月	time
# 30	683	685	昨天	time
# 30	707	709	昨天	time
# 30	750	752	平溪	location
# 30	773	775	平溪	location
# 30	799	802	大學池	location
# 30	830	832	大兒	family
# 30	857	860	高爾夫	location
# 30	893	896	五十塊	money
# 30	1161	1164	許醫師	name
# 30	1406	1410	四十五歲	time
# 30	1461	1464	陳醫師	name
# 30	1629	1631	明翰	name
# 30	1635	1640	林明翰醫師	name
# 30	1893	1896	許醫師	name
# 30	2042	2045	三個月	time
# 30	2202	2205	三千五	money
# 30	2332	2335	陳醫師	name
# 30	2781	2784	陳醫師	name
# 30	2820	2822	武漢	location
# 30	2834	2836	七號	time
# 30	2840	2842	七號	time
# 30	3044	3047	四十歲	time
# 30	3109	3113	四十五歲	time
# 30	3154	3158	四十五歲	time
# 30	3616	3619	七月底	time
# 7	11	14	林醫師	name
# 7	80	83	九點四	med_exam
# 7	90	92	十萬	money
# 7	164	166	三周	time
# 7	199	204	五月十二號	time
# 7	257	260	九個月	time
# 7	264	268	九個半月	time
# 7	272	275	九個月	time
# 7	282	285	九個月	time
# 7	292	296	九個半月	time
# 7	332	335	九個月	time
# 7	348	351	六個月	time
# 7	490	492	小明	name
# 7	784	788	一個禮拜	time
# 7	789	791	五天	time
# 7	855	857	紐約	location
# 7	863	869	今天六月十三	time
# 7	1043	1047	六月十三	time
# 7	1048	1050	小美	name
# 7	1130	1133	四個月	time
# 7	1164	1167	林醫師	name
# 7	1321	1325	明年一月	time
# 7	1329	1331	一月	time
# 7	1460	1463	林醫師	name
# 7	1497	1500	林醫師	name
# 7	1657	1660	陳醫師	name
# 183	21	24	張醫師	name
# 183	1687	1689	昨天	time
# 183	1781	1786	三十天中間	time
# 141	302	307	9月11號	time
# 141	668	670	今年	time
# 141	737	739	今年	time
# 141	1076	1080	陽明醫院	location
# 141	1325	1329	陽明醫院	location
# 141	1351	1357	阿大次郎醫師	name
# 141	1491	1493	五年	time
# 141	1504	1506	今年	time
# 141	1508	1510	今年	time
# 141	1511	1513	五年	time
# 141	1654	1660	10月19號	time
# 44	693	697	九月三號	time
# 44	795	798	四五八	med_exam
# 44	922	926	七二點三	time
# 44	930	934	七二點三	time
# 44	1284	1286	小華	name
# 44	1290	1292	小明	name
# 44	1486	1489	一二三	med_exam
# 144	52	57	7月13號	time
# 144	115	117	五十	time
# 144	126	128	五十	time
# 144	188	190	陸陸	name
# 144	611	615	四個禮拜	time
# 144	620	624	四個禮拜	time
# 144	937	940	五十歲	time
# 144	1005	1009	兩三個月	time
# 144	1015	1019	兩三個月	time
# 144	1185	1190	3月12號	time
# 144	1210	1214	1月7號	time
# 144	1225	1227	1月	time
# 144	1242	1248	1月7跟1月	time
# 144	1299	1303	12月2	time
# 144	1321	1325	12月2	time
# 144	1333	1335	1月	time
# 144	1388	1390	1月	time
# 144	1616	1618	5月	time
# 144	1752	1754	高雄	location
# 144	1764	1766	高雄	location
# 144	1790	1792	竹縣	location
# 144	1799	1801	竹縣	location
# 144	1807	1810	新竹縣	location
# 144	1844	1846	新竹	location
# 144	1914	1916	村莊	location
# 144	2001	2003	四周	time
# 144	2013	2016	小林村	location
# 144	2019	2021	四周	time
# 144	2030	2032	大溪	location
# 144	2039	2041	大溪	location
# 144	2050	2052	大溪	location
# 144	2282	2285	三個月	time
# 144	2311	2314	三個月	time
# 60	122	125	三年多	time
# 60	130	133	三年多	time
# 60	247	250	三年多	time
# 119	173	176	上個月	time
# 119	331	333	8月	time
# 119	343	347	10月中	time
# 119	378	380	小明	name
# 119	1096	1100	10月初	time
# 119	1128	1130	台中	location
# 119	1136	1138	彰化	location
# 119	1143	1145	彰化	location
# 119	1173	1177	彰化醫院	location
# 119	1216	1221	陳明明醫師	name
# 119	1250	1255	陳明明醫師	name
# 108	459	461	三年	time
# 108	466	468	三年	time
# 108	484	486	三年	time
# 108	879	882	兩個月	time
# 108	1090	1093	兩個月	time
# 108	1102	1106	12月中	time
# 108	1117	1121	12月中	time
# 108	1145	1149	12月中	time
# 108	1202	1206	12月中	time
# 108	1243	1246	12月	time
# 108	1330	1335	禮拜二下午	time
# 108	1336	1341	禮拜三早上	time
# 108	1694	1697	12月	time
# 108	1702	1706	12月1	time
# 108	1717	1721	12月中	time
# 108	1722	1726	12月底	time
# 108	1840	1844	12月中	time
# 108	1845	1849	12月底	time
# 108	1855	1858	禮拜三	time
# 108	1859	1861	早上	time
# 108	1871	1874	禮拜三	time
# 108	1880	1885	禮拜四早上	time
# 108	1886	1891	禮拜二下午	time
# 108	2010	2014	木葉診所	location
# 108	2024	2026	木葉	location
# 108	2030	2033	木葉路	location
# 108	2048	2050	木葉	location
# 108	2055	2058	木葉路	location
# 108	2080	2084	小櫻醫師	name
# 108	2115	2118	禮拜二	time
# 108	2123	2126	禮拜二	time
# 108	2130	2134	12月1	time
# 108	2136	2138	早上	time
# 108	2146	2148	下午	time
# 108	2156	2158	下午	time
# 108	2207	2212	禮拜三下午	time
# 108	2219	2224	禮拜三下午	time
# 108	2232	2235	這禮拜	time
# 108	2236	2238	禮拜	time
# 108	2246	2248	禮拜	time
# 108	2280	2282	木葉	location
# 108	2283	2285	木葉	location
# 108	2291	2293	木葉	location
# 108	2369	2373	12月中	time
# 108	2374	2378	12月底	time
# 108	2474	2477	禮拜三	time
# 108	2480	2483	12月	time
# 108	2495	2497	下午	time
# 108	2532	2535	禮拜二	time
# 108	2539	2542	禮拜三	time
# 108	2545	2550	禮拜二下午	time
# 108	2583	2585	下午	time
# 108	2773	2775	木葉	location
# 108	2781	2785	木葉診所	location
# 70	280	283	兩個月	time
# 70	293	296	兩個月	time
# 70	303	306	兩個月	time
# 70	409	414	6月10日	time
# 70	448	453	早上6點前	time
# 70	483	488	晚上6點前	time
# 106	298	302	上上個月	time
# 106	308	312	上上個月	time
# 106	321	325	上上個月	time
# 106	456	459	六月中	time
# 106	490	492	三月	time
# 106	508	510	四月	time
# 106	515	517	四月	time
# 106	522	524	4月	time
# 106	536	538	四月	time
# 106	618	620	四月	time
# 106	775	779	下下禮拜	time
# 106	780	782	今天	time
# 106	840	843	三個月	time
# 106	968	971	兩個月	time
# 106	983	986	兩個月	time
# 106	1004	1008	三個禮拜	time
# 106	1110	1114	下下禮拜	time
# 106	1116	1120	下下禮拜	time
# 130	3	5	小明	name
# 130	190	192	小明	name
# 130	214	219	5月23號	time
# 130	477	479	小明	name
# 130	488	493	5月27號	time
# 130	738	742	兩個禮拜	time
# 130	775	779	兩個禮拜	time
# 130	801	805	兩個禮拜	time
# 130	989	993	今天櫻木	time
# 130	1062	1067	9月24號	time
# 3	67	71	三個禮拜	time
# 3	105	110	上上個禮拜	time
# 3	115	120	上上個禮拜	time
# 3	125	130	上上個禮拜	time
# 3	168	171	林醫師	name
# 3	261	266	上上個禮拜	time
# 64	415	420	五月三十號	time
# 64	430	434	今天晚上	time
# 64	444	449	今天禮拜五	time
# 64	461	465	晚上八點	time
# 64	519	524	兩個小時前	time
# 64	595	597	五月	time
# 64	601	607	五月三十一號	time
# 64	656	660	六月一號	time
# 64	665	669	六月一號	time
# 64	703	705	六月	time
# 64	706	710	六月一號	time
# 64	720	726	六月一號晚上	time
# 64	1153	1156	四十八	time
# 64	1199	1204	四十八小時	time
# 182	64	66	台東	location
# 182	109	111	昨天	time
# 182	112	114	昨天	time
# 182	883	891	surprise	profession
# 182	910	918	everyday	profession
# 182	1994	1996	六月	time
# 182	1997	2001	今天六月	time
# 182	2002	2004	四號	time
# 182	2007	2011	六月三號	time
# 182	2012	2016	六月五號	time
# 182	2017	2021	六月六號	time
# 182	2048	2054	今天晚上十點	time
# 182	2195	2197	五號	time
# 182	2230	2232	八點	time
# 182	2250	2252	八點	time
# 182	2295	2299	六月七號	time
# 182	2312	2314	八點	time
# 182	2740	2742	五點	time
# 182	3082	3084	今年	time
# 182	3086	3088	五年	time
# 128	38	40	昨天	time
# 128	1339	1341	昨天	time
# 128	1393	1397	兩個禮拜	time
# 128	1645	1649	下個禮拜	time
# 128	2074	2078	一個禮拜	time
# 128	2080	2084	兩個禮拜	time
# 128	2115	2119	兩個禮拜	time
# 128	2225	2228	下禮拜	time
# 128	2239	2243	下下禮拜	time
# 128	2376	2382	ＧＯＯＧＬＥ	profession
# 128	2392	2398	ＧＯＯＧＬＥ	profession
# 128	2457	2463	ＧＯＯＧＬＥ	profession
# 128	2679	2682	禮拜五	time
# 128	2764	2766	昨天	time
# 128	3074	3078	兩個禮拜	time
# 128	3080	3082	早上	time
# 128	3084	3086	下午	time
# 128	3266	3269	禮拜三	time
# 128	3270	3272	早上	time
# 128	3278	3283	7月13號	time
# 151	116	119	十二月	time
# 151	123	126	十二月	time
# 151	136	139	十二月	time
# 151	153	158	一百三十九	med_exam
# 151	162	167	一百三十九	med_exam
# 151	199	201	竹科	location
# 151	224	226	竹科	location
# 151	388	391	九十七	med_exam
# 151	645	650	十二月十九	time
# 151	661	663	四號	time
